# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import cv2
import tensorflow as tf
import tensorflow.keras.layers as tfl
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import  Dense, BatchNormalization, ReLU, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from google.colab import drive
from google.colab import files
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 11
#       9 from tensorflow.keras.utils import to_categorical
#      10 from sklearn.model_selection import train_test_split
# ---> 11 from google.colab import drive
#      12 from google.colab import files
#
# ModuleNotFoundError: No module named 'google.colab'

# %% [markdown]
# # **Load Data ==================================**

# %% [markdown]
# Basketball --> 0
# Football-->1
# Rowing-->2
# Swimming-->3
# Tennis-->4
# Yoga-->5

# %%
img = cv2.imread("./drive/MyDrive/Colab Notebooks/NN DataSet/train/Basketball_1.jpg")

# %%
img.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-32ad6cb7aa56> in <module>
# ----> 1 img.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# # **PreProcessing ==================================**

# %% [markdown]
# # **Model1 ==================================**

# %% [markdown]
# tf.keras.layers.Conv2D(
# 2, 3, activation='relu', padding="same", input_shape=input_shape[1:])(x)
#
#
# model_lstm_1.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001,)
# ,loss=tf.keras.losses.SparseCategoricalCrossentropy()
#             ,metrics=["accuracy"])
#
#
#
#
# model_lstm_1.fit(train_ds.batch(32), epochs=256, )
#
#
# model_lstm_1.summary()

# %% [markdown]
# # **Test Model1 ==================================**

# %% [markdown]
# # **Model2 ==================================**

# %%
model_1 = Sequential([
    tf.keras.Input(shape=(40,1662),),

])

# %% [markdown]
# # **Test Model2 ==================================**
